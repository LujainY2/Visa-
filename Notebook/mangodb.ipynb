# %%
'''
mongodb+srv://lujainy527_db_user:<db_password>@cluster0.nxzpygl.mongodb.net/?appName=Cluster0
'''
# Out:
# '\nmongodb+srv://lujainy527_db_user:<db_password>@cluster0.nxzpygl.mongodb.net/?appName=Cluster0\n'
